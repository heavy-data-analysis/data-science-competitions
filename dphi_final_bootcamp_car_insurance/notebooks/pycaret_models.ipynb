# %%
import os
import joblib

import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from scipy import stats

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder, RobustScaler, OneHotEncoder

import shap
import optuna
import category_encoders as ce
import optuna.visualization as vis

import xgboost as xgb
import lightgbm as lgb
import catboost as cat

from pycaret.classification import *

from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('../data/clean_train4.csv')
test = pd.read_csv('../data/clean_test4.csv')

# %%
print(train.info())
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2802 entries, 0 to 2801
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  2802 non-null   int64
#  1   job_type             2802 non-null   int64
#  2   marital_status       2802 non-null   int64
#  3   education_level      2802 non-null   int64
#  4   balance_amt          2802 non-null   float64
#  5   household_insurance  2802 non-null   int64
#  6   car_loan             2802 non-null   int64
#  7   communication        2802 non-null   int64
#  8   last_contact_day     2802 non-null   int64
#  9   last_contact_month   2802 non-null   int64
#  10  no_of_contacts       2802 non-null   int64
#  11  prev_attempts        2802 non-null   int64
#  12  Outcome              2802 non-null   int64
#  13  car_insurance        2802 non-null   int64
#  14  call_duration        2802 non-null   float64
#  15  zero_neg_balance     2802 non-null   int64
# dtypes: float64(2), int64(14)
# memory usage: 350.4 KB
# None
#    age  job_type  marital_status  education_level  balance_amt  \
# 0   47         1               1                0  1112.000000
# 1   46         4               1                2     1.312372
# 2   36         7               2                1   281.000000
# 3   32         9               2                1   540.000000
# 4   30         0               2                1   315.000000
#
#    household_insurance  car_loan  communication  last_contact_day  \
# 0                    1         0              0                12
# 1                    0         1              0                14
# 2                    1         0              0                15
# 3                    0         1              0                28
# 4                    1         0              0                13
#
#    last_contact_month  no_of_contacts  prev_attempts  Outcome  car_insurance  \
# 0                   8               1              0        3              0
# 1                   8               3              1        1              1
# 2                   8               1              0        3              1
# 3                   4               1              0        3              1
# 4                   8               3              4        0              1
#
#    call_duration  zero_neg_balance
# 0       2.150000                 0
# 1     293.300000                 0
# 2       8.583333                 0
# 3      12.500000                 0
# 4      14.733333                 0

# %%
num_feats = test.columns.tolist()

data_setup = setup(
    data=train,
    target='car_insurance',
    train_size=0.75,
    numeric_features=num_feats,
    fold_shuffle=True,
)
# Out:
# <style  type="text/css" >
# </style><table id="T_2ccd9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2ccd9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2ccd9_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2ccd9_row0_col1" class="data row0 col1" >1451</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2ccd9_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_2ccd9_row1_col1" class="data row1 col1" >car_insurance</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2ccd9_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_2ccd9_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2ccd9_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_2ccd9_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2ccd9_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_2ccd9_row4_col1" class="data row4 col1" >(2802, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2ccd9_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_2ccd9_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2ccd9_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_2ccd9_row6_col1" class="data row6 col1" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2ccd9_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_2ccd9_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2ccd9_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_2ccd9_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2ccd9_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_2ccd9_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_2ccd9_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_2ccd9_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_2ccd9_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_2ccd9_row11_col1" class="data row11 col1" >(2101, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_2ccd9_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_2ccd9_row12_col1" class="data row12 col1" >(701, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_2ccd9_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_2ccd9_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_2ccd9_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_2ccd9_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_2ccd9_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_2ccd9_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_2ccd9_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_2ccd9_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_2ccd9_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_2ccd9_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_2ccd9_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_2ccd9_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_2ccd9_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_2ccd9_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_2ccd9_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_2ccd9_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_2ccd9_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_2ccd9_row21_col1" class="data row21 col1" >b4dc</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_2ccd9_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_2ccd9_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_2ccd9_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_2ccd9_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2ccd9_level0_row24" class="row_heading level0 row24" >24</th>
#                         <td id="T_2ccd9_row24_col0" class="d
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-3981c1c7bfa5> in <module>
#       1 num_feats = test.columns.tolist()
#       2
# ----> 3 data_setup = setup(
#       4     data=train,
#       5     target='car_insurance',
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/pycaret/classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     578         log_plots = ["auc", "confusion_matrix", "feature"]
#     579
# --> 580     return pycaret.internal.tabular.setup(
#     581         ml_usecase="classification",
#     582         available_plots=available_plots,
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/pycaret/internal/tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1748     logger.info(f"display_container: {len(display_container)}")
#    1749
# -> 1750     logger.info(str(prep_pipe))
#    1751     logger.info("setup() succesfully completed......................................")
#    1752
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/sklearn/base.py in __repr__(self, N_CHAR_MAX)
#     258             n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW)
#     259
# --> 260         repr_ = pp.pformat(self)
#     261
#     262         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~/miniconda3/envs/data-science/lib/python3.8/pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~/miniconda3/envs/data-science/lib/python3.8/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~/miniconda3/envs/data-science/lib/python3.8/pprint.py in _repr(self, object, context, level)
#     402
#     403     def _repr(self, object, context, level):
# --> 404         repr, readable, recursive = self.format(object, context.copy(),
#     405                                                 self._depth, level)
#     406         if not readable:
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/sklearn/utils/_pprint.py in format(self, object, context, maxlevels, level)
#     178
#     179     def format(self, object, context, maxlevels, level):
# --> 180         return _safe_repr(object, context, maxlevels, level,
#     181                           changed_only=self._changed_only)
#     182
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     434             krepr, kreadable, krecur = saferepr(
#     435                 k, context, maxlevels, level, changed_only=changed_only)
# --> 436             vrepr, vreadable, vrecur = saferepr(
#     437                 v, context, maxlevels, level, changed_only=changed_only)
#     438             append("%s=%s" % (krepr.strip("'"), vrepr))
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     403         level += 1
#     404         for o in object:
# --> 405             orepr, oreadable, orecur = _safe_repr(
#     406                 o, context, maxlevels, level, changed_only=changed_only)
#     407             append(orepr)
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     403         level += 1
#     404         for o in object:
# --> 405             orepr, oreadable, orecur = _safe_repr(
#     406                 o, context, maxlevels, level, changed_only=changed_only)
#     407             append(orepr)
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     425             params = _changed_params(object)
#     426         else:
# --> 427             params = object.get_params(deep=False)
#     428         components = []
#     429         append = components.append
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/sklearn/base.py in get_params(self, deep)
#     193         out = dict()
#     194         for key in self._get_param_names():
# --> 195             value = getattr(self, key)
#     196             if deep and hasattr(value, 'get_params'):
#     197                 deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
best_model = compare_models(n_select=2)
# Out:
# <style  type="text/css" >
#     #T_2e13d_ th {
#           text-align: left;
#     }#T_2e13d_row0_col0,#T_2e13d_row0_col4,#T_2e13d_row1_col0,#T_2e13d_row1_col1,#T_2e13d_row1_col2,#T_2e13d_row1_col3,#T_2e13d_row1_col4,#T_2e13d_row1_col5,#T_2e13d_row1_col6,#T_2e13d_row1_col7,#T_2e13d_row2_col0,#T_2e13d_row2_col1,#T_2e13d_row2_col2,#T_2e13d_row2_col3,#T_2e13d_row2_col4,#T_2e13d_row2_col5,#T_2e13d_row2_col6,#T_2e13d_row2_col7,#T_2e13d_row3_col0,#T_2e13d_row3_col1,#T_2e13d_row3_col2,#T_2e13d_row3_col3,#T_2e13d_row3_col4,#T_2e13d_row3_col5,#T_2e13d_row3_col6,#T_2e13d_row3_col7,#T_2e13d_row4_col0,#T_2e13d_row4_col1,#T_2e13d_row4_col2,#T_2e13d_row4_col3,#T_2e13d_row4_col4,#T_2e13d_row4_col5,#T_2e13d_row4_col6,#T_2e13d_row4_col7,#T_2e13d_row5_col0,#T_2e13d_row5_col1,#T_2e13d_row5_col2,#T_2e13d_row5_col3,#T_2e13d_row5_col4,#T_2e13d_row5_col5,#T_2e13d_row5_col6,#T_2e13d_row5_col7,#T_2e13d_row6_col0,#T_2e13d_row6_col1,#T_2e13d_row6_col2,#T_2e13d_row6_col3,#T_2e13d_row6_col4,#T_2e13d_row6_col5,#T_2e13d_row6_col6,#T_2e13d_row6_col7,#T_2e13d_row7_col0,#T_2e13d_row7_col1,#T_2e13d_row7_col2,#T_2e13d_row7_col3,#T_2e13d_row7_col4,#T_2e13d_row7_col5,#T_2e13d_row7_col6,#T_2e13d_row7_col7,#T_2e13d_row8_col0,#T_2e13d_row8_col1,#T_2e13d_row8_col2,#T_2e13d_row8_col3,#T_2e13d_row8_col4,#T_2e13d_row8_col5,#T_2e13d_row8_col6,#T_2e13d_row8_col7,#T_2e13d_row9_col0,#T_2e13d_row9_col1,#T_2e13d_row9_col2,#T_2e13d_row9_col3,#T_2e13d_row9_col5,#T_2e13d_row9_col6,#T_2e13d_row9_col7,#T_2e13d_row10_col0,#T_2e13d_row10_col1,#T_2e13d_row10_col2,#T_2e13d_row10_col3,#T_2e13d_row10_col5,#T_2e13d_row10_col6,#T_2e13d_row10_col7,#T_2e13d_row11_col0,#T_2e13d_row11_col1,#T_2e13d_row11_col2,#T_2e13d_row11_col3,#T_2e13d_row11_col4,#T_2e13d_row11_col5,#T_2e13d_row11_col6,#T_2e13d_row11_col7,#T_2e13d_row12_col0,#T_2e13d_row12_col1,#T_2e13d_row12_col2,#T_2e13d_row12_col3,#T_2e13d_row12_col4,#T_2e13d_row12_col5,#T_2e13d_row12_col6,#T_2e13d_row12_col7,#T_2e13d_row13_col0,#T_2e13d_row13_col1,#T_2e13d_row13_col2,#T_2e13d_row13_col3,#T_2e13d_row13_col4,#T_2e13d_row13_col5,#T_2e13d_row13_col6,#T_2e13d_row13_col7,#T_2e13d_row14_col0,#T_2e13d_row14_col1,#T_2e13d_row14_col2,#T_2e13d_row14_col3,#T_2e13d_row14_col4,#T_2e13d_row14_col5,#T_2e13d_row14_col6,#T_2e13d_row14_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_2e13d_row0_col1,#T_2e13d_row0_col2,#T_2e13d_row0_col3,#T_2e13d_row0_col5,#T_2e13d_row0_col6,#T_2e13d_row0_col7,#T_2e13d_row9_col4,#T_2e13d_row10_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_2e13d_row0_col8,#T_2e13d_row1_col8,#T_2e13d_row2_col8,#T_2e13d_row3_col8,#T_2e13d_row4_col8,#T_2e13d_row5_col8,#T_2e13d_row6_col8,#T_2e13d_row7_col8,#T_2e13d_row8_col8,#T_2e13d_row11_col8,#T_2e13d_row12_col8,#T_2e13d_row13_col8,#T_2e13d_row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_2e13d_row9_col8,#T_2e13d_row10_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_2e13d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e13d_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_2e13d_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_2e13d_row0_col1" class="data row0 col1" >0.8653</td>
#                         <td id="T_2e13d_row0_col2" class="data row0 col2" >0.9418</td>
#                         <td id="T_2e13d_row0_col3" class="data row0 col3" >0.8903</td>
#                         <td id="T_2e13d_row0_col4" class="data row0 col4" >0.8753</td>
#                         <td id="T_2e13d_row0_col5" class="data row0 col5" >0.8824</td>
#                         <td id="T_2e13d_row0_col6" class="data row0 col6" >0.7248</td>
#                         <td id="T_2e13d_row0_col7" class="data row0 col7" >0.7258</td>
#                         <td id="T_2e13d_row0_col8" class="data row0 col8" >1.8060</td>
#             </tr>
#             <tr>
#                         <th id="T_2e13d_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#                         <td id="T_2e13d_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_2e13d_row1_col1" class="data row1 col1" >0.8629</td>
#                         <td id="T_2e13d_row1_col2" class="data row1 col2" >0.9373</td>
#                         <td id="T_2e13d_row1_col3" class="data row1 col3" >0.8819</td>
#                         <td id="T_2e13d_row1_col4" class="data row1 col4" >0.8780</td>
#                         <td id="T_2e13d_row1_col5" class="data row1 col5" >0.8797</td>
#                         <td id="T_2e13d_row1_col6" class="data row1 col6" >0.7204</td>
#                         <td id="T_2e13d_row1_col7" class="data row1 col7" >0.7209</td>
#                         <td id="T_2e13d_row1_col8" class="data row1 col8" >0.9700</td>
#             </tr>
#             <tr>
#                         <th id="T_2e13d_level0_row2" class="row_heading level0 row2" >xgboost</th>
#                         <td id="T_2e13d_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_2e13d_row2_col1" class="data row2 col1" >0.8596</td>
#                         <td id="T_2e13d_row2_col2" class="data row2 col2" >0.9365</td>
#                         <td id="T_2e13d_row2_col3" class="data row2 col3" >0.8777</td>
#                         <td id="T_2e13d_row2_col4" class="data row2 col4" >0.8763</td>
#                         <td id="T_2e13d_row2_col5" class="data row2 col5" >0.8765</td>
#                         <td id="T_2e13d_row2_col6" class="data row2 col6" >0.7137</td>
#                         <td id="T_2e13d_row2_col7" class="data row2 col7" >0.7148</td>
#                         <td id="T_2e13d_row2_col8" class="data row2 col8" >0.7120</td>
#             </tr>
#             <tr>
#                         <th id="T_2e13d_level0_row3" class="row_heading level0 row3" >rf</th>
#                         <td id="T_2e13d_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#                         <td id="T_2e13d_row3_col1" class="data row3 col1" >0.8572</td>
#                         <td id="T_2e13d_row3_col2" class="data row3 col2" >0.9341</td>
#                         <td id="T_2e13d_row3_col3" class="data row3 col3" >0.8803</td>
#                         <td id="T_2e13d_row3_col4" class="data row3 col4" >0.8707</td>
#                         <td id="T_2e13d_row3_col5" class="data row3 col5" >0.8751</td>
#                         <td id="T_2e13d_row3_col6" class="data row3 col6" >0.7084</td>
#                         <td id="T_2e13d_row3_col7" class="data row3 col7" >0.7091</td>
#                         <td id="T_2e13d_row3_col8" class="data row3 col8" >0.2630</td>
#             </tr>
#             <tr>
#                         <th id="T_2e13d_level0_row4" class="row_heading level0 row4" >gbc</th>
#                         <td id="T_2e13d_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_2e13d_row4_col1" class="data row4 col1" >0.8563</td>
#                         <td id="T_2e13d_row4_col2" class="data row4 col2" >0.9338</td>
#                         <td id="T_2e13d_row4_col3" class="data row4 col3" >0.8819</td>
#                         <td id="

# %%
cat = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_64d3b_row10_col0,#T_64d3b_row10_col1,#T_64d3b_row10_col2,#T_64d3b_row10_col3,#T_64d3b_row10_col4,#T_64d3b_row10_col5,#T_64d3b_row10_col6{
#             background:  yellow;
#         }</style><table id="T_64d3b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64d3b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_64d3b_row0_col0" class="data row0 col0" >0.8578</td>
#                         <td id="T_64d3b_row0_col1" class="data row0 col1" >0.9359</td>
#                         <td id="T_64d3b_row0_col2" class="data row0 col2" >0.9250</td>
#                         <td id="T_64d3b_row0_col3" class="data row0 col3" >0.8409</td>
#                         <td id="T_64d3b_row0_col4" class="data row0 col4" >0.8810</td>
#                         <td id="T_64d3b_row0_col5" class="data row0 col5" >0.7055</td>
#                         <td id="T_64d3b_row0_col6" class="data row0 col6" >0.7104</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_64d3b_row1_col0" class="data row1 col0" >0.8667</td>
#                         <td id="T_64d3b_row1_col1" class="data row1 col1" >0.9473</td>
#                         <td id="T_64d3b_row1_col2" class="data row1 col2" >0.9000</td>
#                         <td id="T_64d3b_row1_col3" class="data row1 col3" >0.8710</td>
#                         <td id="T_64d3b_row1_col4" class="data row1 col4" >0.8852</td>
#                         <td id="T_64d3b_row1_col5" class="data row1 col5" >0.7263</td>
#                         <td id="T_64d3b_row1_col6" class="data row1 col6" >0.7268</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_64d3b_row2_col0" class="data row2 col0" >0.8524</td>
#                         <td id="T_64d3b_row2_col1" class="data row2 col1" >0.9442</td>
#                         <td id="T_64d3b_row2_col2" class="data row2 col2" >0.8417</td>
#                         <td id="T_64d3b_row2_col3" class="data row2 col3" >0.8938</td>
#                         <td id="T_64d3b_row2_col4" class="data row2 col4" >0.8670</td>
#                         <td id="T_64d3b_row2_col5" class="data row2 col5" >0.7015</td>
#                         <td id="T_64d3b_row2_col6" class="data row2 col6" >0.7031</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_64d3b_row3_col0" class="data row3 col0" >0.8762</td>
#                         <td id="T_64d3b_row3_col1" class="data row3 col1" >0.9501</td>
#                         <td id="T_64d3b_row3_col2" class="data row3 col2" >0.9083</td>
#                         <td id="T_64d3b_row3_col3" class="data row3 col3" >0.8790</td>
#                         <td id="T_64d3b_row3_col4" class="data row3 col4" >0.8934</td>
#                         <td id="T_64d3b_row3_col5" class="data row3 col5" >0.7458</td>
#                         <td id="T_64d3b_row3_col6" class="data row3 col6" >0.7464</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_64d3b_row4_col0" class="data row4 col0" >0.8762</td>
#                         <td id="T_64d3b_row4_col1" class="data row4 col1" >0.9364</td>
#                         <td id="T_64d3b_row4_col2" class="data row4 col2" >0.8992</td>
#                         <td id="T_64d3b_row4_col3" class="data row4 col3" >0.8843</td>
#                         <td id="T_64d3b_row4_col4" class="data row4 col4" >0.8917</td>
#                         <td id="T_64d3b_row4_col5" class="data row4 col5" >0.7472</td>
#                         <td id="T_64d3b_row4_col6" class="data row4 col6" >0.7474</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_64d3b_row5_col0" class="data row5 col0" >0.8619</td>
#                         <td id="T_64d3b_row5_col1" class="data row5 col1" >0.9321</td>
#                         <td id="T_64d3b_row5_col2" class="data row5 col2" >0.8824</td>
#                         <td id="T_64d3b_row5_col3" class="data row5 col3" >0.8750</td>
#                         <td id="T_64d3b_row5_col4" class="data row5 col4" >0.8787</td>
#                         <td id="T_64d3b_row5_col5" class="data row5 col5" >0.7184</td>
#                         <td id="T_64d3b_row5_col6" class="data row5 col6" >0.7185</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_64d3b_row6_col0" class="data row6 col0" >0.8857</td>
#                         <td id="T_64d3b_row6_col1" class="data row6 col1" >0.9566</td>
#                         <td id="T_64d3b_row6_col2" class="data row6 col2" >0.8908</td>
#                         <td id="T_64d3b_row6_col3" class="data row6 col3" >0.9060</td>
#                         <td id="T_64d3b_row6_col4" class="data row6 col4" >0.8983</td>
#                         <td id="T_64d3b_row6_col5" class="data row6 col5" >0.7679</td>
#                         <td id="T_64d3b_row6_col6" class="data row6 col6" >0.7680</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_64d3b_row7_col0" class="data row7 col0" >0.9095</td>
#                         <td id="T_64d3b_row7_col1" class="data row7 col1" >0.9597</td>
#                         <td id="T_64d3b_row7_col2" class="data row7 col2" >0.9496</td>
#                         <td id="T_64d3b_row7_col3" class="data row7 col3" >0.8968</td>
#                         <td id="T_64d3b_row7_col4" class="data row7 col4" >0.9224</td>
#                         <td id="T_64d3b_row7_col5" class="data row7 col5" >0.8141</td>
#                         <td id="T_64d3b_row7_col6" class="data row7 col6" >0.8160</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_64d3b_row8_col0" class="data row8 col0" >0.8190</td>
#                         <td id="T_64d3b_row8_col1" class="data row8 col1" >0.9189</td>
#                         <td id="T_64d3b_row8_col2" class="data row8 col2" >0.8487</td>
#                         <td id="T_64d3b_row8_col3" class="data row8 col3" >0.8347</td>
#                         <td id="T_64d3b_row8_col4" class="data row8 col4" >0.8417</td>
#                         <td id="T_64d3b_row8_col5" class="data row8 col5" >0.6306</td>
#                         <td id="T_64d3b_row8_col6" class="data row8 col6" >0.6307</td>
#             </tr>
#             <tr>
#                         <th id="T_64d3b_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_64d3b_row9_col0" class="data row9 col0" >0.8476</td>
#                         <td id="T_64d3b_row9_col1" class="data row9 col1" >0.9372</td>
#                         <td id="T_64d3b_row9_col2" class="data row9 col2" >0.8571</td>
#                         <td id="T_64d3b_row9_col3" class="data row9 col3" >0.8718</td>
#                         <td id="T_64d3b_row9_col4" class="data row9 col4" >0.8644</td>
#                         <td id="T_64d3b_row9_col5" class="data row9 col5" >0.6905</td>
#                         <td id=

# %%
lgb = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_3542b_row10_col0,#T_3542b_row10_col1,#T_3542b_row10_col2,#T_3542b_row10_col3,#T_3542b_row10_col4,#T_3542b_row10_col5,#T_3542b_row10_col6{
#             background:  yellow;
#         }</style><table id="T_3542b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3542b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3542b_row0_col0" class="data row0 col0" >0.8626</td>
#                         <td id="T_3542b_row0_col1" class="data row0 col1" >0.9399</td>
#                         <td id="T_3542b_row0_col2" class="data row0 col2" >0.9167</td>
#                         <td id="T_3542b_row0_col3" class="data row0 col3" >0.8527</td>
#                         <td id="T_3542b_row0_col4" class="data row0 col4" >0.8835</td>
#                         <td id="T_3542b_row0_col5" class="data row0 col5" >0.7164</td>
#                         <td id="T_3542b_row0_col6" class="data row0 col6" >0.7192</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3542b_row1_col0" class="data row1 col0" >0.8667</td>
#                         <td id="T_3542b_row1_col1" class="data row1 col1" >0.9437</td>
#                         <td id="T_3542b_row1_col2" class="data row1 col2" >0.8750</td>
#                         <td id="T_3542b_row1_col3" class="data row1 col3" >0.8898</td>
#                         <td id="T_3542b_row1_col4" class="data row1 col4" >0.8824</td>
#                         <td id="T_3542b_row1_col5" class="data row1 col5" >0.7285</td>
#                         <td id="T_3542b_row1_col6" class="data row1 col6" >0.7287</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3542b_row2_col0" class="data row2 col0" >0.8476</td>
#                         <td id="T_3542b_row2_col1" class="data row2 col1" >0.9378</td>
#                         <td id="T_3542b_row2_col2" class="data row2 col2" >0.8500</td>
#                         <td id="T_3542b_row2_col3" class="data row2 col3" >0.8793</td>
#                         <td id="T_3542b_row2_col4" class="data row2 col4" >0.8644</td>
#                         <td id="T_3542b_row2_col5" class="data row2 col5" >0.6906</td>
#                         <td id="T_3542b_row2_col6" class="data row2 col6" >0.6911</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3542b_row3_col0" class="data row3 col0" >0.8905</td>
#                         <td id="T_3542b_row3_col1" class="data row3 col1" >0.9519</td>
#                         <td id="T_3542b_row3_col2" class="data row3 col2" >0.9083</td>
#                         <td id="T_3542b_row3_col3" class="data row3 col3" >0.9008</td>
#                         <td id="T_3542b_row3_col4" class="data row3 col4" >0.9046</td>
#                         <td id="T_3542b_row3_col5" class="data row3 col5" >0.7761</td>
#                         <td id="T_3542b_row3_col6" class="data row3 col6" >0.7761</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3542b_row4_col0" class="data row4 col0" >0.8857</td>
#                         <td id="T_3542b_row4_col1" class="data row4 col1" >0.9362</td>
#                         <td id="T_3542b_row4_col2" class="data row4 col2" >0.8992</td>
#                         <td id="T_3542b_row4_col3" class="data row4 col3" >0.8992</td>
#                         <td id="T_3542b_row4_col4" class="data row4 col4" >0.8992</td>
#                         <td id="T_3542b_row4_col5" class="data row4 col5" >0.7673</td>
#                         <td id="T_3542b_row4_col6" class="data row4 col6" >0.7673</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3542b_row5_col0" class="data row5 col0" >0.8476</td>
#                         <td id="T_3542b_row5_col1" class="data row5 col1" >0.9266</td>
#                         <td id="T_3542b_row5_col2" class="data row5 col2" >0.8571</td>
#                         <td id="T_3542b_row5_col3" class="data row5 col3" >0.8718</td>
#                         <td id="T_3542b_row5_col4" class="data row5 col4" >0.8644</td>
#                         <td id="T_3542b_row5_col5" class="data row5 col5" >0.6905</td>
#                         <td id="T_3542b_row5_col6" class="data row5 col6" >0.6907</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3542b_row6_col0" class="data row6 col0" >0.9048</td>
#                         <td id="T_3542b_row6_col1" class="data row6 col1" >0.9557</td>
#                         <td id="T_3542b_row6_col2" class="data row6 col2" >0.8992</td>
#                         <td id="T_3542b_row6_col3" class="data row6 col3" >0.9304</td>
#                         <td id="T_3542b_row6_col4" class="data row6 col4" >0.9145</td>
#                         <td id="T_3542b_row6_col5" class="data row6 col5" >0.8071</td>
#                         <td id="T_3542b_row6_col6" class="data row6 col6" >0.8077</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3542b_row7_col0" class="data row7 col0" >0.8667</td>
#                         <td id="T_3542b_row7_col1" class="data row7 col1" >0.9466</td>
#                         <td id="T_3542b_row7_col2" class="data row7 col2" >0.9076</td>
#                         <td id="T_3542b_row7_col3" class="data row7 col3" >0.8640</td>
#                         <td id="T_3542b_row7_col4" class="data row7 col4" >0.8852</td>
#                         <td id="T_3542b_row7_col5" class="data row7 col5" >0.7264</td>
#                         <td id="T_3542b_row7_col6" class="data row7 col6" >0.7276</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3542b_row8_col0" class="data row8 col0" >0.8095</td>
#                         <td id="T_3542b_row8_col1" class="data row8 col1" >0.9043</td>
#                         <td id="T_3542b_row8_col2" class="data row8 col2" >0.8403</td>
#                         <td id="T_3542b_row8_col3" class="data row8 col3" >0.8264</td>
#                         <td id="T_3542b_row8_col4" class="data row8 col4" >0.8333</td>
#                         <td id="T_3542b_row8_col5" class="data row8 col5" >0.6111</td>
#                         <td id="T_3542b_row8_col6" class="data row8 col6" >0.6113</td>
#             </tr>
#             <tr>
#                         <th id="T_3542b_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3542b_row9_col0" class="data row9 col0" >0.8476</td>
#                         <td id="T_3542b_row9_col1" class="data row9 col1" >0.9299</td>
#                         <td id="T_3542b_row9_col2" class="data row9 col2" >0.8655</td>
#                         <td id="T_3542b_row9_col3" class="data row9 col3" >0.8655</td>
#                         <td id="T_3542b_row9_col4" class="data row9 col4" >0.8655</td>
#                         <td id="T_3542b_row9_col5" class="data row9 col5" >0.6897</td>
#                         <td id=

# %%
evaluate_model(cat)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
best_model
# Out:
# [<catboost.core.CatBoostClassifier at 0x7f702a7d63a0>,
#  LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                 importance_type='split', learning_rate=0.1, max_depth=-1,
#                 min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                 n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                 random_state=1451, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                 subsample=1.0, subsample_for_bin=200000, subsample_freq=0)]

# %%
ensembled_model = ensemble_model([cat, lgb], fold=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5940f9cb9894> in <module>
# ----> 1 ensembled_model = ensemble_model([cat, lgb], fold=5)
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/pycaret/classification.py in ensemble_model(estimator, method, fold, n_estimators, round, choose_better, optimize, fit_kwargs, groups, verbose)
#    1192     """
#    1193
# -> 1194     return pycaret.internal.tabular.ensemble_model(
#    1195         estimator=estimator,
#    1196         method=method,
#
# ~/miniconda3/envs/data-science/lib/python3.8/site-packages/pycaret/internal/tabular.py in ensemble_model(estimator, method, fold, n_estimators, round, choose_better, optimize, fit_kwargs, groups, verbose, display)
#    4665     # Check for estimator
#    4666     if not hasattr(estimator, "fit"):
# -> 4667         raise ValueError(
#    4668             f"Estimator {estimator} does not have the required fit() method."
#    4669         )
#
# ValueError: Estimator [<catboost.core.CatBoostClassifier object at 0x7f704ac18250>, LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1451, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)] does not have the required fit() method.

# %%
final_model = finalize_model(best_model)

# %%
preds = predict_model(final_model, data=test)
preds.head()
# Out:
#    age  job_type  marital_status  education_level  balance_amt  \
# 0   65         5               1                1      20806.0
# 1   36         4               1                2        900.0
# 2   37         4               1                2       6771.0
# 3   30         4               2                2          0.0
# 4   41         4               1                2        328.0
#
#    household_insurance  car_loan  communication  last_contact_day  \
# 0                    0         0              1                 7
# 1                    1         0              0                14
# 2                    0         0              0                 6
# 3                    0         0              0                13
# 4                    1         0              0                28
#
#    last_contact_month  no_of_contacts  prev_attempts  Outcome  call_duration  \
# 0                   0               2              0        3       8.716667
# 1                   8               2              0        3       7.916667
# 2                  11               1              1        2       5.616667
# 3                   8               2              0        3     974.450000
# 4                   5              12              0        3       1.083333
#
#    zero_neg_balance  Label   Score
# 0                 0      1  0.7714
# 1                 0      0  0.6538
# 2                 0      1  0.9770
# 3                 1      1  0.9938
# 4                 0      0  0.9978

# %%
sub = pd.DataFrame({
    'prediction': preds['Label'].astype(int)
})
print(sub.shape)
print(sub.value_counts())
sub.head()
# Out:
# (935, 1)
# prediction
# 1             549
# 0             386
# dtype: int64
#    prediction
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0

# %%
sub.to_csv('../submissions/pycaret1.csv', index=False)
