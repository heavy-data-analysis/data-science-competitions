# %%
from pycaret.regression import *

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('../data/clean_train1.csv')
test = pd.read_csv('../data/clean_test1.csv')

# %%
print(train.info())
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287836 entries, 0 to 287835
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Year                287836 non-null  int64
#  1   OG                  287836 non-null  int64
#  2   Dept                287836 non-null  int64
#  3   Union               287836 non-null  int64
#  4   JF                  287836 non-null  int64
#  5   EI                  287836 non-null  int64
#  6   Salaries            287836 non-null  int64
#  7   Overtime            287836 non-null  int64
#  8   H/D                 287836 non-null  float64
#  9   YT                  287836 non-null  int64
#  10  Total_Compensation  287836 non-null  int64
# dtypes: float64(1), int64(10)
# memory usage: 24.2 MB
# None
#    Year  OG  Dept  Union  JF     EI  Salaries  Overtime       H/D  YT  \
# 0     2   0    45     57  28   6725     12196         0      0.00   0
# ...

# %%
# ign_feats = ['Year', 'OG', 'Dept','Union', 'JF', 'YT']
num_feats = test.columns.tolist()

data_setup = setup(
    data=train,
    target='Total_Compensation',
#     ignore_features=ign_feats,
    numeric_features=num_feats,
    fold_shuffle=True,
    preprocess=False,
)
# Out:
# <style  type="text/css" >
# </style><table id="T_2b96b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b96b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2b96b_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2b96b_row0_col1" class="data row0 col1" >3194</td>
#             </tr>
#             <tr>
#                         <th id="T_2b96b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2b96b_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_2b96b_row1_col1" class="data row1 col1" >Total_Compensation</td>
#             </tr>
#             <tr>
# ...

# %%
cat = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_0192c_row10_col0,#T_0192c_row10_col1,#T_0192c_row10_col2,#T_0192c_row10_col3,#T_0192c_row10_col4,#T_0192c_row10_col5{
#             background:  yellow;
#         }</style><table id="T_0192c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0192c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0192c_row0_col0" class="data row0 col0" >3100.0654</td>
#                         <td id="T_0192c_row0_col1" class="data row0 col1" >38077362.2853</td>
# ...

# %%
lgb = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_9fdbe_row10_col0,#T_9fdbe_row10_col1,#T_9fdbe_row10_col2,#T_9fdbe_row10_col3,#T_9fdbe_row10_col4,#T_9fdbe_row10_col5{
#             background:  yellow;
#         }</style><table id="T_9fdbe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9fdbe_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9fdbe_row0_col0" class="data row0 col0" >3268.7847</td>
#                         <td id="T_9fdbe_row0_col1" class="data row0 col1" >40069924.7823</td>
# ...

# %%
best_models = compare_models(n_select=3, sort='RMSE')
# Out:
# IntProgress(value=0, description='Processing: ', max=99)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 15:14:23
# Status     . . . . . . . . . . . . . . . . . .         Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Regressor
# <style  type="text/css" >
#     #T_94a69_ th {
#           text-align: left;
# ...
